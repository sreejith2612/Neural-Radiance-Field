# %%
import numpy as np
images = np.load("preprocessed_images.npy")

# %%
data = np.load(r"C:\Users\sreej\Downloads\tiny_nerf_data (1).npz")
images = data["images"]

# %%
print("Datatype of the preprocessed images array:", images.dtype)
# Out:
# Datatype of the preprocessed images array: float32

# %%
is_tensor = torch.is_tensor(images)
print("Are the preprocessed images stored as a PyTorch tensor?", is_tensor)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 is_tensor = torch.is_tensor(images)
#       2 print("Are the preprocessed images stored as a PyTorch tensor?", is_tensor)
#
# NameError: name 'torch' is not defined

# %%
import matplotlib.pyplot as plt

# Print all the images
for i, img in enumerate(images):
    # Display the image
    print(img.shape)
    plt.figure()
    plt.imshow(img)
    plt.title(f"Image {i+1}")
    plt.axis('off')
    plt.show()
# Out:
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
# (100, 100, 3)
